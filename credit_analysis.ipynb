# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv('data.csv',low_memory= False)

# %%
pwd
# Out:
# 'C:\\Users\\Dell\\OneDrive\\Documents\\Project-Edtech'

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 8CA7-3B22
#
#  Directory of C:\Users\Dell\OneDrive\Documents\Project-Edtech
#
# 27-06-2025  22:41    <DIR>          .
# 27-06-2025  22:41    <DIR>          ..
# 27-06-2025  22:39    <DIR>          .ipynb_checkpoints
# 06-04-2021  13:50       332,748,422 data.csv
# 21-06-2025  21:53           355,236 Research project.pdf
# 27-06-2025  22:41             1,707 Untitled.ipynb
#                3 File(s)    333,105,365 bytes
#                3 Dir(s)  133,931,425,792 bytes free

# %%
df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#    int_rate  installment grade sub_grade  ... il_util open_rv_12m open_rv_24m  \
# 0     10.65       162.87     B        B2  ...     NaN         NaN         NaN
# 1     15.27        59.83     C        C4  ...     NaN         NaN         NaN
# 2     15.96        84.33     C        C5  ...     NaN         NaN         NaN
# 3     13.49       339.31     C        C1  ...     NaN         NaN         NaN
# 4     12.69        67.79     B        B5  ...     NaN         NaN         NaN
#
# ...

# %%
df.info().isnull.sum
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 855969 entries, 0 to 855968
# Data columns (total 73 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           855969 non-null  int64
#  1   member_id                    855969 non-null  int64
#  2   loan_amnt                    855969 non-null  int64
#  3   funded_amnt                  855969 non-null  int64
#  4   funded_amnt_inv              855969 non-null  float64
#  5   term                         855969 non-null  object
#  6   int_rate                     855969 non-null  float64
#  7   installment                  855969 non-null  float64
#  8   grade                        855969 non-null  object
#  9   sub_grade                    855969 non-null  object
#  10  emp_title                    806526 non-null  object
#  11  emp_length                   812908 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# id                       0
# member_id                0
# loan_amnt                0
# funded_amnt              0
# funded_amnt_inv          0
#                      ...
# total_rev_hi_lim     67313
# inq_fi              842681
# total_cu_tl         842681
# inq_last_12m        842681
# default_ind              0
# Length: 73, dtype: int64

# %%
df.dtypes
# Out:
# id                    int64
# member_id             int64
# loan_amnt             int64
# funded_amnt           int64
# funded_amnt_inv     float64
#                      ...
# total_rev_hi_lim    float64
# inq_fi              float64
# total_cu_tl         float64
# inq_last_12m        float64
# default_ind           int64
# Length: 73, dtype: object

# %%
df['last_pymnt_d'].head()
# Out:
# 0    01-01-2015
# 1    01-04-2013
# 2    01-06-2014
# 3    01-01-2015
# 4    01-01-2016
# Name: last_pymnt_d, dtype: object

# %%
df['last_pymnt_d']= pd.to_datetime(df['last_pymnt_d'])

# %%
df['last_pymnt_d']
# Out:
# 0        2015-01-01
# 1        2013-01-04
# 2        2014-01-06
# 3        2015-01-01
# 4        2016-01-01
#             ...
# 855964   2016-01-01
# 855965   2016-01-01
# 855966   2016-01-01
# 855967   2016-01-01
# 855968   2016-01-01
# Name: last_pymnt_d, Length: 855969, dtype: datetime64[ns]

# %%
df['term'].value_counts()
# Out:
# term
# 36 months    600221
# 60 months    255748
# Name: count, dtype: int64

# %%
clean_term= df['term'].str.replace('months','')

# %%
clean_term
# Out:
# 0          36
# 1          60
# 2          36
# 3          36
# 4          60
#           ...
# 855964     36
# 855965     36
# 855966     60
# 855967     60
# 855968     36
# Name: term, Length: 855969, dtype: object

# %%
df['term']=pd.to_numeric(clean_term)

# %%
df['term']
# Out:
# 0         36
# 1         60
# 2         36
# 3         36
# 4         60
#           ..
# 855964    36
# 855965    36
# 855966    60
# 855967    60
# 855968    36
# Name: term, Length: 855969, dtype: int64

# %%
df['default_ind']
# Out:
# 0         0
# 1         1
# 2         0
# 3         0
# 4         0
#          ..
# 855964    0
# 855965    0
# 855966    0
# 855967    0
# 855968    0
# Name: default_ind, Length: 855969, dtype: int64
